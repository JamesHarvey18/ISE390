# %% [markdown]
# # This file was used to concatenate the audio files for each speaker into one single file for each of them.

# %%
import pydub

path1 = "/Users/James/Documents/SBU/ISE390/SpeechProject/Audio/id10001/"
path2 = "/Users/James/Documents/SBU/ISE390/SpeechProject/Audio/id10002/"
path3 = "/Users/James/Documents/SBU/ISE390/SpeechProject/Audio/id10003/"
path4 = "/Users/James/Documents/SBU/ISE390/SpeechProject/Audio/id10004/"
path5 = "/Users/James/Documents/SBU/ISE390/SpeechProject/Audio/id10005/"
path6 = "/Users/James/Documents/SBU/ISE390/SpeechProject/Audio/id10006/"
path7 = "/Users/James/Documents/SBU/ISE390/SpeechProject/Audio/id10007/"
path8 = "/Users/James/Documents/SBU/ISE390/SpeechProject/Audio/id10008/"
path9 = "/Users/James/Documents/SBU/ISE390/SpeechProject/Audio/id10009/"
path10 = "/Users/James/Documents/SBU/ISE390/SpeechProject/Audio/id10010/"


speaker_files = []
speaker_files.append([path1 + "1zcIwhmdeo4/00001.wav", path1 + "1zcIwhmdeo4/00002.wav", path1 + "1zcIwhmdeo4/00003.wav",
        path1 + "7gWzIy6yIIk/00001.wav", path1 + "7gWzIy6yIIk/00002.wav", path1 + "7gWzIy6yIIk/00003.wav",
        path1 + "7gWzIy6yIIk/00004.wav", path1 + "7w0IBEWc9Qw/00001.wav", path1 + "7w0IBEWc9Qw/00002.wav",
        path1 + "7w0IBEWc9Qw/00003.wav", path1 + "7w0IBEWc9Qw/00004.wav", path1 + "7w0IBEWc9Qw/00005.wav",
        path1 + "7w0IBEWc9Qw/00006.wav", path1 + "7w0IBEWc9Qw/00007.wav", path1 + "7w0IBEWc9Qw/00008.wav",
        path1 + "7w0IBEWc9Qw/00009.wav", path1 + "7w0IBEWc9Qw/00010.wav"])

speaker_files.append([path2 + "6WO410QOeuo/00001.wav", path2 + "6WO410QOeuo/00002.wav", path2 + "6WO410QOeuo/00003.wav",
                 path2 + "6WO410QOeuo/00004.wav", path2 + "6WO410QOeuo/00005.wav", path2 + "6WO410QOeuo/00006.wav",
                 path2 + "6WO410QOeuo/00007.wav", path2 + "6WO410QOeuo/00008.wav", path2 + "6WO410QOeuo/00009.wav",
                 path2 + "6WO410QOeuo/00010.wav", path2 + "6WO410QOeuo/00011.wav"])

speaker_files.append([path3 + "5ablueV_1tw/00001.wav", path3 + "5ablueV_1tw/00002.wav", path3 + "5ablueV_1tw/00003.wav",
                 path3 + "5ablueV_1tw/00004.wav", path3 + "5ablueV_1tw/00005.wav", path3 + "5ablueV_1tw/00006.wav",
                 path3 + "5ablueV_1tw/00007.wav", path3 + "5ablueV_1tw/00008.wav", path3 + "5ablueV_1tw/00009.wav",
                 path3 + "5ablueV_1tw/00010.wav", path3 + "5ablueV_1tw/00011.wav", path3 + "5ablueV_1tw/00012.wav"])

speaker_files.append([path4 + "bIZQaEVuATQ/00001.wav", path4 + "bIZQaEVuATQ/00002.wav", path4 + "bIZQaEVuATQ/00003.wav",
                 path4 + "bIZQaEVuATQ/00004.wav", path4 + "bIZQaEVuATQ/00005.wav", path4 + "bIZQaEVuATQ/00006.wav",
                 path4 + "bIZQaEVuATQ/00007.wav", path4 + "bIZQaEVuATQ/00008.wav", path4 + "bIZQaEVuATQ/00009.wav",
                 path4 + "bIZQaEVuATQ/00010.wav", path4 + "bIZQaEVuATQ/00011.wav", path4 + "bIZQaEVuATQ/00012.wav"])

speaker_files.append([path5 + "38_N-A-QOUo/00001.wav", path5 + "38_N-A-QOUo/00002.wav", path5 + "38_N-A-QOUo/00003.wav",
                 path5 + "38_N-A-QOUo/00004.wav", path5 + "38_N-A-QOUo/00005.wav", path5 + "38_N-A-QOUo/00006.wav",
                 path5 + "38_N-A-QOUo/00007.wav", path5 + "38_N-A-QOUo/00008.wav", path5 + "38_N-A-QOUo/00009.wav",
                 path5 + "38_N-A-QOUo/00010.wav", path5 + "38_N-A-QOUo/00011.wav", path5 + "38_N-A-QOUo/00012.wav"])

speaker_files.append([path6 + "3MwyuwaVE50/00001.wav", path6 + "3MwyuwaVE50/00002.wav", path6 + "3MwyuwaVE50/00003.wav",
                 path6 + "3MwyuwaVE50/00004.wav", path6 + "3MwyuwaVE50/00005.wav", path6 + "3MwyuwaVE50/00006.wav",
                 path6 + "3MwyuwaVE50/00007.wav", path6 + "3MwyuwaVE50/00008.wav", path6 + "3MwyuwaVE50/00009.wav",
                 path6 + "3MwyuwaVE50/00010.wav", path6 + "3MwyuwaVE50/00011.wav", path6 + "3MwyuwaVE50/00012.wav"])

speaker_files.append([path7 + "CzQPAaPrC-E/00001.wav", path7 + "CzQPAaPrC-E/00002.wav", path7 + "CzQPAaPrC-E/00003.wav",
                 path7 + "CzQPAaPrC-E/00004.wav", path7 + "CzQPAaPrC-E/00005.wav", path7 + "CzQPAaPrC-E/00006.wav",
                 path7 + "CzQPAaPrC-E/00007.wav", path7 + "CzQPAaPrC-E/00008.wav", path7 + "CzQPAaPrC-E/00009.wav",
                 path7 + "CzQPAaPrC-E/00010.wav", path7 + "CzQPAaPrC-E/00011.wav", path7 + "CzQPAaPrC-E/00012.wav"])

speaker_files.append([path8 + "r4IZRsEGDFs/00001.wav", path8 + "r4IZRsEGDFs/00002.wav", path8 + "r4IZRsEGDFs/00003.wav",
                 path8 + "r4IZRsEGDFs/00004.wav", path8 + "r4IZRsEGDFs/00005.wav", path8 + "r4IZRsEGDFs/00006.wav",
                 path8 + "r4IZRsEGDFs/00007.wav", path8 + "r4IZRsEGDFs/00008.wav", path8 + "r4IZRsEGDFs/00009.wav",
                 path8 + "r4IZRsEGDFs/00010.wav", path8 + "r4IZRsEGDFs/00011.wav", path8 + "r4IZRsEGDFs/00012.wav"])

speaker_files.append([path9 + "sQIqfA-I_Ew/00001.wav", path9 + "sQIqfA-I_Ew/00002.wav", path9 + "sQIqfA-I_Ew/00003.wav",
                 path9 + "sQIqfA-I_Ew/00004.wav", path9 + "sQIqfA-I_Ew/00005.wav", path9 + "sQIqfA-I_Ew/00006.wav",
                 path9 + "sQIqfA-I_Ew/00007.wav", path9 + "sQIqfA-I_Ew/00008.wav", path9 + "sQIqfA-I_Ew/00009.wav",
                 path9 + "sQIqfA-I_Ew/00010.wav", path9 + "sQIqfA-I_Ew/00011.wav", path9 + "sQIqfA-I_Ew/00012.wav"])

speaker_files.append([path10 + "zJHub1wydMw/00001.wav", path10 + "zJHub1wydMw/00002.wav", path10 + "zJHub1wydMw/00003.wav",
                  path10 + "zJHub1wydMw/00004.wav", path10 + "zJHub1wydMw/00005.wav", path10 + "zJHub1wydMw/00006.wav",
                  path10 + "zJHub1wydMw/00007.wav", path10 + "zJHub1wydMw/00008.wav", path10 + "zJHub1wydMw/00009.wav",
                  path10 + "zJHub1wydMw/00010.wav"])

for i in range(len(speaker_files)):
    combined_sounds = pydub.AudioSegment.empty()
    export_path = "/Users/James/Documents/SBU/ISE390/SpeechProject/Audio/ConcatenatedAudio/speaker" + str(i+1) + ".wav"
    for j in speaker_files[i]:
        combined_sounds = combined_sounds + pydub.AudioSegment.from_wav(j)
    
    combined_sounds.export(export_path, format="wav")
